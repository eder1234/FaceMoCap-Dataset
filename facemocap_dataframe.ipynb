# %%
import pickle
import pandas as pd

# Load control_df and patients_df
with open('control_df.pkl', 'rb') as f:
    control_df = pickle.load(f)
with open('patients_df.pkl', 'rb') as f:
    patients_df = pickle.load(f)

# Concatenate control_df and patients_df
facemocap_df = pd.concat([control_df, patients_df], axis=0)
facemocap_df.sample(50)
# Out:
#                 File name                                       Original SPC  \
# 179    P23_D1_M4x10e4.csv  [[27.7326, 197.407, 573.63, 99.257, 183.632, 6...
# 566    P21_D1_M4x10e6.csv  [[-6.28234, 161.946, 582.928, -13.1606, 153.03...
# 21              M1_05.csv  [[281.725, 25.3751, 1157.73, 258.703, 20.9897,...
# 512   P17_D1_M4x10_e1.csv  [[94.2647, 91.0148, 565.265, 99.2863, 74.6912,...
# 53            AT01_M4.csv  [[-66.5296, 361.165, 1132.78, -57.1497, 375.81...
# 498    P22_D1_M2x10e5.csv  [[14.6709, 162.298, 645.157, 13.7, 155.85, 613...
# 213           CN01_P2.csv  [[-162.69, 560.542, 650.374, -154.674, 539.003...
# 107    P18_D2_M4x10e1.csv  [[69.8625, 191.811, 631.113, 69.7603, 187.46, ...
# 434    P21_D1_M5x10e5.csv  [[6.65347, 163.775, 576.284, 1.01784, 155.365,...
# 115           CR01_M2.csv  [[70.3908, 67.7807, 1057.87, 59.8323, 90.7823,...
# 170          CAD01_M1.csv  [[12.8152, 221.442, 715.091, 12.8316, 204.613,...
# ...

# %%
import numpy as np
# Verify nan value in facemocap_df["Date"][401]
np.isnan(facemocap_df["Date"][401])
# Out:
# True

# %%
for index, row in facemocap_df.iterrows():
    if row["Date"] == "":
        facemocap_df["Date"][index] = np.nan
print(facemocap_df["Date"][401])
# Out:
# nan
# /tmp/ipykernel_13423/825249926.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   facemocap_df["Date"][index] = np.nan

# %%
facemocap_df.sample(50)
# Out:
#                 File name                                       Original SPC  \
# 311   P17_D1_M2x10_e9.csv  [[99.9999, 92.8386, 563.529, 105.281, 76.7555,...
# 495   P23_D1_M3YOx5e4.csv  [[113.284, 195.62, 652.287, 43.5705, 212.22, 5...
# 76              QS_M4.csv  [[97.6898, -8.4523, 1161.87, 96.727, -6.17391,...
# 421   P17_D1_M3x10_e1.csv  [[97.3526, 91.0999, 560.898, 103.061, 75.1357,...
# 74            AD01_M3.csv  [[230.021, 9.06553, 1171.79, 237.485, 33.4863,...
# 371    P13_D1_M5x10e1.csv  [[43.1834, 180.436, 596.882, 42.7812, 162.777,...
# 103          AVP01_M2.csv  [[119.571, 23.4832, 1135.25, 112.194, 32.2327,...
# 80       P17_D1_M3_e1.csv  [[96.1687, 84.5015, 575.237, 99.4843, 68.2204,...
# 167    P13_D1_M5x10e4.csv  [[37.6602, 177.31, 594.095, 37.7846, 159.743, ...
# 143    P13_D1_M2x10e6.csv  [[9.33772, 177.393, 597.126, 8.71768, 160.292,...
# 241    P23_D1_M5x10e1.csv  [[23.7016, 202.36, 570.434, 20.2984, 173.04, 5...
# ...

# %%
facemocap_df.to_pickle("facemocap_df.pkl")
