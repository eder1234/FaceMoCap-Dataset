# %%
import os

# Create a list that contains the folders in '/home/rodriguez/Documents/Sujets Sains'
root = '/home/rodriguez/Documents/Sujets Sains'
frs_folders = os.listdir(root)
print(frs_folders)
# Out:
# ['MP01', 'ABD01', 'RS01', 'AG01', 'PS01', 'NL01', 'CN02', 'AT01', 'BT01', 'MM01', 'AA01', 'AD01', 'QS', 'JB01', 'AVP01', 'CR01', 'CR', 'SIMOVI_Sain', 'GG01', 'TP01', 'SD01', 'CG03', 'FRS02', 'CAD01', 'FRS01', 'RL01', 'Readme.md', 'LN01', 'CN01', 'SB01', 'CD01', 'CG02', 'AC01']

# %%
# Remove 'SIMOVI_Sain' from the list
frs_folders.remove('SIMOVI_Sain')
frs_folders.remove("Readme.md")

# %%
import pandas as pd

frs_df = pd.DataFrame()
frs_error_list = []
for folder in frs_folders:
    filepath = os.path.join(root, folder)
    csv_files = os.listdir(filepath)
    for csv in csv_files:
        csv_path = os.path.join(filepath, csv)
        try:
            csv_content = pd.read_csv(csv_path, header=None, skiprows=5, usecols=[i+2 for i in range(324)])
            
            csv_array = csv_content.to_numpy()
            # If "x" is in csv, set repetitive = True
            if "x" in csv:
                repetitive = True
            else:
                repetitive = False
            frs_df = pd.concat([frs_df, pd.DataFrame({'File name': csv, 'Original SPC': [csv_array], 
                                                      "Name": folder, "Experimentator": "François-Régis", 
                                                      'MoCap platform': "UTC", "Pathology": False,
                                                      "Repetitive": repetitive})], 
                                                      ignore_index=True)
        except:
            print("Error while reading csv file. File: " + csv_path + " ignored.")
            frs_error_list.append(csv_path)
frs_df["Movement"] = ""
frs_df["Date"] = ""
# Out:
# Error while reading csv file. File: /home/rodriguez/Documents/Sujets Sains/MP01/.~lock.MP01_M05.csv# ignored.
# Error while reading csv file. File: /home/rodriguez/Documents/Sujets Sains/AG01/Readme.md ignored.
# Error while reading csv file. File: /home/rodriguez/Documents/Sujets Sains/BT01/BT01_M3.csv ignored.
# Error while reading csv file. File: /home/rodriguez/Documents/Sujets Sains/JB01/JB01_Statique.csv ignored.
# Error while reading csv file. File: /home/rodriguez/Documents/Sujets Sains/TP01/TP01_M3.csv ignored.
# Error while reading csv file. File: /home/rodriguez/Documents/Sujets Sains/CG02/CG02_M1.csv ignored.

# %%
frs_df.head(20)
# Out:
#          File name                                       Original SPC   Name  \
# 0     MP01_M05.csv  [[82.0149, 336.328, 1414.31, 80.2184, 347.124,...   MP01
# 1     MP01_M04.csv  [[80.96, 334.745, 1412.78, 79.7897, 345.616, 1...   MP01
# 2     MP01_M02.csv  [[81.5083, 338.102, 1415.29, 80.0191, 349.103,...   MP01
# 3     MP01_M01.csv  [[77.6899, 336.869, 1408.5, 77.865, 347.594, 1...   MP01
# 4     MP01_M03.csv  [[81.3165, 337.815, 1412.57, 80.4275, 348.679,...   MP01
# 5       ABD_M2.csv  [[32.8159, 14.1725, 1126.25, 24.6743, -4.42407...  ABD01
# 6       ABD_M3.csv  [[32.2918, 19.8075, 1129.87, 24.9686, 1.14563,...  ABD01
# 7       ABD_M5.csv  [[29.4192, 18.0311, 1129.96, 22.0913, -0.32626...  ABD01
# 8       ABD_M4.csv  [[30.3669, 18.3804, 1129.96, 22.9641, -0.20488...  ABD01
# 9       ABD_M1.csv  [[34.5202, 13.0599, 1124.71, 26.0475, -5.49102...  ABD01
# 10  RS01_M3bis.csv  [[-67.5657, 317.184, 1112.27, -64.3415, 330.87...   RS01
# 11     RS01_M1.csv  [[-69.0724, 331.063, 1115.33, -65.6108, 344.34...   RS01
# 12  RS01_M4bis.csv  [[-65.8253, 320.464, 1111.69, -62.8886, 334.24...   RS01
# 13     RS01_M5.csv  [[-64.751, 325.435, 1113.33, -61.9178, 339.001...   RS01
# 14     RS01_M2.csv  [[-72.764, 334.614, 1117.46, -69.7468, 347.946...   RS01
# 15     AG01_M5.csv  [[-134.434, 175.296, 672.29, -131.905, 157.775...   AG01
# 16   AG01_M4_2.csv  [[-136.005, 172.976, 670.868, -133.302, 155.54...   AG01
# 17     AG01_M3.csv  [[-134.577, 175.527, 674.642, -133.032, 158.27...   AG01
# 18     AG01_M2.csv  [[-137.031, 169.609, 674.994, -135.053, 152.47...   AG01
# 19     AG01_M1.csv  [[-138.291, 168.582, 674.552, -136.209, 151.79...   AG01
#
#     Experimentator MoCap platform  Pathology  Repetitive Movement Date
# 0   François-Régis            UTC      False       False
# 1   François-Régis            UTC      False       False
# 2   François-Régis            UTC      False       False
# 3   François-Régis            UTC      False       False
# 4   François-Régis            UTC      False       False
# 5   François-Régis            UTC      False       False
# 6   François-Régis            UTC      False       False
# 7   François-Régis            UTC      False       False
# 8   François-Régis            UTC      False       False
# 9   François-Régis            UTC      False       False
# 10  François-Régis            UTC      False       False
# 11  François-Régis            UTC      False       False
# 12  François-Régis            UTC      False       False
# 13  François-Régis            UTC      False       False
# 14  François-Régis            UTC      False       False
# 15  François-Régis            UTC      False       False
# 16  François-Régis            UTC      False       False
# 17  François-Régis            UTC      False       False
# 18  François-Régis            UTC      False       False
# 19  François-Régis            UTC      False       False

# %%
# Determine the movement and the date of each file
for index, row in frs_df.iterrows():
    M0X = row["File name"][-7:-4]
    MX = row["File name"][-6:-4]
    MXbis = row["File name"][-9:-4]
    MX_ = row["File name"][-8:-5]
    MXx = row["File name"][-8:-5]
    
    if (M0X == 'M05' or MX == 'M5' or MXbis == 'M5bis' or MX_ == 'M5_' or MXx == 'M5x'):
        frs_df.loc[index, "Movement"] = 5
    if (M0X == 'M04' or MX == 'M4' or MXbis == 'M4bis' or MX_ == 'M4_' or MXx == 'M4x'):
        frs_df.loc[index, "Movement"] = 4
    if (M0X == 'M03' or MX == 'M3' or MXbis == 'M3bis' or MX_ == 'M3_' or MXx == 'M3x'):
        frs_df.loc[index, "Movement"] = 3
    if (M0X == 'M02' or MX == 'M2' or MXbis == 'M2bis' or MX_ == 'M2_' or MXx == 'M2x'):
        frs_df.loc[index, "Movement"] = 2
    if (M0X == 'M01' or MX == 'M1' or MXbis == 'M1bis' or MX_ == 'M1_' or MXx == 'M1x'):
        frs_df.loc[index, "Movement"] = 1

# %%
frs_df.head(50)
# Out:
#            File name                                       Original SPC  \
# 0       MP01_M05.csv  [[82.0149, 336.328, 1414.31, 80.2184, 347.124,...
# 1       MP01_M04.csv  [[80.96, 334.745, 1412.78, 79.7897, 345.616, 1...
# 2       MP01_M02.csv  [[81.5083, 338.102, 1415.29, 80.0191, 349.103,...
# 3       MP01_M01.csv  [[77.6899, 336.869, 1408.5, 77.865, 347.594, 1...
# 4       MP01_M03.csv  [[81.3165, 337.815, 1412.57, 80.4275, 348.679,...
# 5         ABD_M2.csv  [[32.8159, 14.1725, 1126.25, 24.6743, -4.42407...
# 6         ABD_M3.csv  [[32.2918, 19.8075, 1129.87, 24.9686, 1.14563,...
# 7         ABD_M5.csv  [[29.4192, 18.0311, 1129.96, 22.0913, -0.32626...
# 8         ABD_M4.csv  [[30.3669, 18.3804, 1129.96, 22.9641, -0.20488...
# 9         ABD_M1.csv  [[34.5202, 13.0599, 1124.71, 26.0475, -5.49102...
# 10    RS01_M3bis.csv  [[-67.5657, 317.184, 1112.27, -64.3415, 330.87...
# 11       RS01_M1.csv  [[-69.0724, 331.063, 1115.33, -65.6108, 344.34...
# 12    RS01_M4bis.csv  [[-65.8253, 320.464, 1111.69, -62.8886, 334.24...
# 13       RS01_M5.csv  [[-64.751, 325.435, 1113.33, -61.9178, 339.001...
# 14       RS01_M2.csv  [[-72.764, 334.614, 1117.46, -69.7468, 347.946...
# 15       AG01_M5.csv  [[-134.434, 175.296, 672.29, -131.905, 157.775...
# 16     AG01_M4_2.csv  [[-136.005, 172.976, 670.868, -133.302, 155.54...
# 17       AG01_M3.csv  [[-134.577, 175.527, 674.642, -133.032, 158.27...
# 18       AG01_M2.csv  [[-137.031, 169.609, 674.994, -135.053, 152.47...
# 19       AG01_M1.csv  [[-138.291, 168.582, 674.552, -136.209, 151.79...
# 20       PS01_M2.csv  [[110.497, 28.2567, 1098.43, 95.2297, 16.0319,...
# 21       PS01_M5.csv  [[109.157, 34.3821, 1104.14, 94.8837, 21.9681,...
# 22       PS01_M4.csv  [[108.423, 33.5088, 1105.03, 94.2414, 21.0263,...
# 23       PS01_M1.csv  [[107.384, 33.5094, 1098.87, 92.4697, 20.756, ...
# 24       PS01_M3.csv  [[108.725, 30.9378, 1101.79, 94.0249, 18.5732,...
# 25       NL01_M5.csv  [[362.871, -65.8605, 1132.4, 350.681, -81.7235...
# 26       NL01_M2.csv  [[360.104, -72.3889, 1128.25, 347.331, -87.996...
# 27       NL01_M3.csv  [[361.012, -67.3205, 1130.77, 348.721, -83.340...
# 28       NL01_M4.csv  [[362.559, -64.771, 1131.6, 350.421, -80.8518,...
# 29       NL01_M1.csv  [[361.744, -74.2685, 1126.08, 348.253, -89.9, ...
# 30       CN03_M4.csv  [[583.447, 59.2101, 1089.2, 579.501, 81.2126, ...
# 31       CN03_P9.csv  [[572.948, 77.4412, 1083.83, 566.246, 99.3174,...
# 32     CN03_M2x3.csv  [[578.92, 59.7416, 1081.72, 574.241, 82.0198, ...
# 33       CN03_P6.csv  [[581.611, 54.5851, 1077.77, 574.38, 76.3643, ...
# 34     CN03_M3x3.csv  [[580.84, 51.9488, 1075.74, 575.998, 74.763, 1...
# 35       CN03_P7.csv  [[580.959, 55.1965, 1073.07, 573.217, 76.7493,...
# 36    CN03_P7bis.csv  [[582.236, 55.6788, 1073.79, 574.72, 77.4655, ...
# 37    CN03_P8bis.csv  [[575.541, 76.5637, 1080.88, 568.21, 98.6464, ...
# 38       CN03_P1.csv  [[598.866, 44.1704, 1074.56, 591.741, 66.061, ...
# 39     CN03_M4x3.csv  [[583.105, 55.1343, 1083.77, 578.812, 77.6629,...
# 40       CN03_M1.csv  [[590.523, 57.8301, 1087.36, 586.284, 79.7008,...
# 41       CN03_P4.csv  [[584.184, 53.2471, 1075.65, 576.119, 74.2552,...
# 42       CN03_M5.csv  [[588.699, 57.9492, 1089.41, 584.834, 80.2258,...
# 43       CN03_M3.csv  [[585.959, 58.3235, 1088.69, 582.142, 80.1968,...
# 44       CN03_P3.csv  [[597.168, 42.0954, 1078.18, 590.511, 63.914, ...
# 45  CN03_M1x3bis.csv  [[576.36, 49.8198, 1081.54, 571.723, 72.4565, ...
# 46       CN03_P2.csv  [[598.312, 41.5568, 1075.56, 591.318, 63.4758,...
# 47       CN03_P5.csv  [[580.539, 55.0363, 1079.91, 573.467, 76.5105,...
# 48  CN03_Complet.csv  [[582.95, 60.5287, 1078.09, 577.528, 82.6151, ...
# 49     CN03_M5x3.csv  [[588.29, 61.6684, 1078.83, 582.945, 83.7873, ...
#
#      Name  Experimentator MoCap platform  Pathology  Repetitive Movement Date
# 0    MP01  François-Régis            UTC      False       False        5
# 1    MP01  François-Régis            UTC      False       False        4
# 2    MP01  François-Régis            UTC      False       False        2
# 3    MP01  François-Régis            UTC      False       False        1
# 4    MP01  François-Régis            UTC      False       False        3
# 5   ABD01  François-Régis            UTC      False       False        2
# 6   ABD01  François-Régis            UTC      False       False        3
# 7   ABD01  François-Régis            UTC      False       False        5
# 8   ABD01  François-Régis            UTC      False       False        4
# 9   ABD01  François-Régis            UTC      False       False        1
# 10   RS01  François-Régis            UTC      False       False        3
# 11   RS01  François-Régis            UTC      False       False        1
# 12   RS01  François-Régis            UTC      False       False        4
# 13   RS01  François-Régis            UTC      False       False        5
# 14   RS01  François-Régis            UTC      False       False        2
# 15   AG01  François-Régis            UTC      False       False        5
# 16   AG01  François-Régis            UTC      False       False        4
# 17   AG01  François-Régis            UTC      False       False        3
# 18   AG01  François-Régis            UTC      False       False        2
# 19   AG01  François-Régis            UTC      False       False        1
# 20   PS01  François-Régis            UTC      False       False        2
# 21   PS01  François-Régis            UTC      False       False        5
# 22   PS01  François-Régis            UTC      False       False        4
# 23   PS01  François-Régis            UTC      False       False        1
# 24   PS01  François-Régis            UTC      False       False        3
# 25   NL01  François-Régis            UTC      False       False        5
# 26   NL01  François-Régis            UTC      False       False        2
# 27   NL01  François-Régis            UTC      False       False        3
# 28   NL01  François-Régis            UTC      False       False        4
# 29   NL01  François-Régis            UTC      False       False        1
# 30   CN02  François-Régis            UTC      False       False        4
# 31   CN02  François-Régis            UTC      False       False
# 32   CN02  François-Régis            UTC      False        True        2
# 33   CN02  François-Régis            UTC      False       False
# 34   CN02  François-Régis            UTC      False        True        3
# 35   CN02  François-Régis            UTC      False       False
# 36   CN02  François-Régis            UTC      False       False
# 37   CN02  François-Régis            UTC      False       False
# 38   CN02  François-Régis            UTC      False       False
# 39   CN02  François-Régis            UTC      False        True        4
# 40   CN02  François-Régis            UTC      False       False        1
# 41   CN02  François-Régis            UTC      False       False
# 42   CN02  François-Régis            UTC      False       False        5
# 43   CN02  François-Régis            UTC      False       False        3
# 44   CN02  François-Régis            UTC      False       False
# 45   CN02  François-Régis            UTC      False        True
# 46   CN02  François-Régis            UTC      False       False
# 47   CN02  François-Régis            UTC      False       False
# 48   CN02  François-Régis            UTC      False       False
# 49   CN02  François-Régis            UTC      False        True        5

# %%
# Save the dataframe in pickle file
frs_df.to_pickle("frs_df.pkl")

# %%
# Create felix_df
